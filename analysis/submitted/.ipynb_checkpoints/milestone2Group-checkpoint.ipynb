# %% [markdown]
# # MILESTONE 2
#
# In this milestone we will get to *finally* minipulate the data we harvested
#
# ---
#
# **Group File**

# %% [markdown]
# ## Objectives to complete
# 1. Task 3 Chaining
# 2. Task 4 Analysis
# 3. Task 5 Research

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from scripts.project_functions import *

data ='../../data/raw/Gamesales.csv'
dfu = unprocessed(data)
dfu
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# 0              76.0          51.0          8       322.0  Nintendo      E
# 1               NaN           NaN        NaN         NaN       NaN    NaN
# 2              82.0          73.0        8.3       709.0  Nintendo      E
# 3              80.0          73.0          8       192.0  Nintendo      E
# 4               NaN           NaN        NaN         NaN       NaN    NaN
# ...             ...           ...        ...         ...       ...    ...
# 16714           NaN           NaN        NaN         NaN       NaN    NaN
# 16715           NaN           NaN        NaN         NaN       NaN    NaN
# 16716           NaN           NaN        NaN         NaN       NaN    NaN
# 16717           NaN           NaN        NaN         NaN       NaN    NaN
# 16718           NaN           NaN        NaN         NaN       NaN    NaN
#
# [16719 rows x 16 columns]

# %%
dfp = load_and_process(data)
dfp
# Out:
#                                           Name Platform  Year_of_Release  \
# 0                                   Darksiders     X360           2010.0
# 1                                   Frogger 3D      3DS           2011.0
# 2     BeyBlade VForce: Super Tournament Battle       GC           2002.0
# 3                    Power Rangers: Wild Force      GBA           2002.0
# 4                     Tenchu: Shadow Assassins      Wii           2008.0
# ...                                        ...      ...              ...
# 6820               Commandos 2: Men of Courage       XB           2002.0
# 6821                           Wrath Unleashed      PS2           2004.0
# 6822                                Kessen III      PS2           2004.0
# 6823                            Cities XL 2012       PC           2011.0
# 6824                   STORM: Frontline Nation       PC           2011.0
#
#          Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0       Action                           THQ      0.67      0.28      0.01
# 1       Action  Konami Digital Entertainment      0.16      0.03      0.00
# 2       Action                         Atari      0.16      0.04      0.00
# 3       Action                           THQ      0.15      0.05      0.00
# 4       Action                       Ubisoft      0.15      0.01      0.03
# ...        ...                           ...       ...       ...       ...
# 6820  Strategy             Eidos Interactive      0.05      0.02      0.00
# 6821  Strategy                     LucasArts      0.04      0.03      0.00
# 6822  Strategy                    Tecmo Koei      0.04      0.03      0.00
# 6823  Strategy        Focus Home Interactive      0.01      0.05      0.00
# 6824  Strategy                       Unknown      0.00      0.01      0.00
#
#       Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# 0            0.10          1.06          83.0          81.0        7.9
# 1            0.01          0.21          54.0          11.0        5.5
# 2            0.01          0.21          33.0           6.0        7.5
# 3            0.00          0.21          55.0           4.0        6.9
# 4            0.01          0.21          70.0          35.0        7.8
# ...           ...           ...           ...           ...        ...
# 6820         0.00          0.07          67.0          12.0        8.4
# 6821         0.01          0.07          64.0          25.0          6
# 6822         0.01          0.07          73.0          26.0        8.1
# 6823         0.01          0.07          61.0          18.0        5.6
# 6824         0.00          0.01          60.0          12.0        7.2
#
#       User_Count                Developer Rating
# 0          292.0              Vigil Games      M
# 1            8.0               Alpha Unit      E
# 2           18.0                   Takara      E
# 3            8.0                  Natsume      E
# 4           24.0                  Acquire      M
# ...          ...                      ...    ...
# 6820         5.0             Pyro Studios      T
# 6821         6.0       Double Helix Games      T
# 6822        20.0                     Koei      T
# 6823        95.0  Monte Cristo Multimedia      E
# 6824        13.0                   SimBin   E10+
#
# [6825 rows x 16 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
df1 = dfp.groupby('Year_of_Release', as_index=False).sum()
df2 = pd.melt(df1, id_vars="Year_of_Release", value_vars=["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales"],var_name ='Region', value_name ='Sales')
ax = sns.catplot(x="Year_of_Release",y="Sales",hue="Region",data = df2,kind ="bar")
ax.fig.set_size_inches(40,5)
plt.show()

# %%
df3 = dfp.groupby('Genre', as_index=False).sum()
df4 = pd.melt(df3, id_vars="Genre", value_vars=["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales"],var_name ='Region', value_name ='Sales')
ax = sns.catplot(x="Genre",y="Sales",hue="Region",data = df4,kind ="bar")
ax.fig.set_size_inches(20,5)
ax.fig.suptitle("Relationship between Game Sales and Genre")
plt.show()

# %% [markdown]
# Action has top sales in the world except Japan. The most popular genre in Japan is Role-Plyaing.
# Adventure, Puzzle and Strategy have lowest sales.

# %%
#df2
ax = sns.lmplot(data=df2, x="Year_of_Release",y="Sales",hue="Region")
ax.fig.set_size_inches(15,10)
plt.show()

# %% [markdown]
# ### Weighted Score based on 45% of critic score and 55% User Score

# %%
dfp.Critic_Score = dfp.Critic_Score.astype(float)
dfp.User_Score = dfp.User_Score.astype(float)
dfp["Weighted Score"] = dfp["Critic_Score"]*0.45 + dfp["User_Score"]*5.5
dfp

# %%
df3 = dfp.groupby('Genre', as_index=False).mean()
ax = sns.catplot(x="Genre",y="Weighted Score",data = df3,kind ="bar" )
ax.fig.set_size_inches(20,5)
plt.show()

# %% [markdown]
# The mean of Weighted Score grouped by Genre shows that the avarages of them are pretty close. However, even though action is the top sales game, the mean of the score is slightly low compared to other categories.

# %%
a4_dims = (7, 15)
fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.boxplot(x="Weighted Score", y="Genre", data=dfp)
ax.set_title('BoxPlot of Weighted Scores by Genre')
ax.set_xlabel("Weighted Score")
ax.set_ylabel("Genre")
ax

# %% [markdown]
# Although the averages of weighted scores group by genre do not have much difference, this figure shows that the weighted score for Racing has a huge gap between its maximum and minimum.

# %%
df5 = dfp.groupby('Publisher', as_index=False).mean()
df5 = df5.sort_values("Weighted Score",ascending = False)
ax = sns.catplot(x="Weighted Score",y="Publisher",data = df5,kind ="bar" )
ax.fig.set_size_inches(10,45)
plt.show()

# %%
ax = sns.pairplot(
    dfp,
    corner=True,
    x_vars=["Year_of_Release", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales","Weighted Score"],
    y_vars=["Year_of_Release", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales","Weighted Score"],
    
)
ax.fig.suptitle("Relationship Game Sales by Region")
ax
