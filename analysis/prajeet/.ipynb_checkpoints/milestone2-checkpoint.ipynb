# %% [markdown]
# # MILESTONE 2
#
# In this milestone we will get to *finally* minipulate the data we harvested
#
# **Prajeets File**

# %% [markdown]
# ## Objectives to complete
# 1. Task 3 Chaining
# 2. Task 4 Analysis
# 3. Task 5 Research

# %% [markdown]
# ## Load in File unprocessed file: ##

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from scripts.project_functions import *

data ='../../data/raw/Gamesales.csv'
dfu = unprocessed(data)
dfu
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# ## Load in File processed file: ##

# %%
dfp = load_and_process(data)
dfp
# Out:
#                                           Name Platform  Year_of_Release  \
# 0                                   Darksiders     X360           2010.0
# 1                                   Frogger 3D      3DS           2011.0
# 2     BeyBlade VForce: Super Tournament Battle       GC           2002.0
# 3                    Power Rangers: Wild Force      GBA           2002.0
# 4                     Tenchu: Shadow Assassins      Wii           2008.0
# ...                                        ...      ...              ...
# 6820               Commandos 2: Men of Courage       XB           2002.0
# 6821                           Wrath Unleashed      PS2           2004.0
# 6822                                Kessen III      PS2           2004.0
# 6823                            Cities XL 2012       PC           2011.0
# 6824                   STORM: Frontline Nation       PC           2011.0
#
#          Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## Data Analysis: ##

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

print("Number of rows and columns respectively:", dfp.shape)
print("Columns in the dataset:", dfp.columns)
# Out:
# Number of rows and columns respectively: (6825, 16)
# Columns in the dataset: Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
dfp.describe(include='float64')
# Out:
#        Year_of_Release     NA_Sales     EU_Sales     JP_Sales  Other_Sales  \
# count      6825.000000  6825.000000  6825.000000  6825.000000  6825.000000
# mean       2007.436777     0.394484     0.236089     0.064158     0.082677
# std           4.211248     0.967385     0.687330     0.287570     0.269871
# min        1985.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2004.000000     0.060000     0.020000     0.000000     0.010000
# 50%        2007.000000     0.150000     0.060000     0.000000     0.020000
# 75%        2011.000000     0.390000     0.210000     0.010000     0.070000
# max        2016.000000    41.360000    28.960000     6.500000    10.570000
#
#        Global_Sales  Critic_Score  Critic_Count    User_Count
# count   6825.000000   6825.000000   6825.000000   6825.000000
# mean       0.777590     70.272088     28.931136    174.722344
# std        1.963443     13.868572     19.224165    587.428538
# ...

# %%
dfp.describe(include='object')
# Out:
#                                            Name Platform   Genre  \
# count                                      6825     6825    6825
# unique                                     4377       17      12
# top     LEGO Star Wars II: The Original Trilogy      PS2  Action
# freq                                          8     1140    1630
#
#               Publisher User_Score  Developer Rating
# count              6825       6825       6825   6825
# unique              262         89       1289      7
# top     Electronic Arts        7.8  EA Canada      T
# freq                944        294        149   2377

# %%
from pandas_profiling import ProfileReport
from ipywidgets import widgets
# Your solution for `pandas_profiling`
profile = ProfileReport(dfp, title="Game Sales Pandas Profiling Report",explorative=True)
#profile
profile.to_notebook_iframe()
