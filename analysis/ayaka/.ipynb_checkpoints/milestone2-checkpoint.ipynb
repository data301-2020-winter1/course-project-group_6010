# %% [markdown]
# # Milestone2
# 1. Build and test your method chain(s)
# 2. Wrap your method chain(s) in a function

# %% [markdown]
# - Step 3

# %% [markdown]
# ## Loading the dataset

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from scripts.project_functions import *

data ='../../data/raw/Gamesales.csv'
dfu = unprocessed(data)
dfu
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
dfp = load_and_process(data)

# %%
dfp.describe(include=[np.number]).T
# Out:
#                   count         mean         std      min      25%      50%  \
# Year_of_Release  6825.0  2007.436777    4.211248  1985.00  2004.00  2007.00
# NA_Sales         6825.0     0.394484    0.967385     0.00     0.06     0.15
# EU_Sales         6825.0     0.236089    0.687330     0.00     0.02     0.06
# JP_Sales         6825.0     0.064158    0.287570     0.00     0.00     0.00
# Other_Sales      6825.0     0.082677    0.269871     0.00     0.01     0.02
# Global_Sales     6825.0     0.777590    1.963443     0.01     0.11     0.29
# Critic_Score     6825.0    70.272088   13.868572    13.00    62.00    72.00
# Critic_Count     6825.0    28.931136   19.224165     3.00    14.00    25.00
# User_Count       6825.0   174.722344  587.428538     4.00    11.00    27.00
#
#                      75%       max
# Year_of_Release  2011.00   2016.00
# NA_Sales            0.39     41.36
# EU_Sales            0.21     28.96
# JP_Sales            0.01      6.50
# ...

# %%
dfp.describe(include=[np.object]).T
# Out:
#            count unique              top  freq
# Name        6825   4377    Madden NFL 07     8
# Platform    6825     17              PS2  1140
# Genre       6825     12           Action  1630
# Publisher   6825    262  Electronic Arts   944
# User_Score  6825     89              7.8   294
# Developer   6825   1289        EA Canada   149
# Rating      6825      7                T  2377

# %% [markdown]
# According to this, top genre is action among 12 genres. PS2 is the top platform. Electronic Arts published 944 games.

# %%
df1 = dfp.groupby('Year_of_Release',as_index=False).sum()
df1
# Out:
#     Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0            1985.0      0.00      0.03      0.00         0.01          0.03
# 1            1988.0      0.00      0.02      0.00         0.01          0.03
# 2            1992.0      0.02      0.00      0.00         0.00          0.03
# 3            1994.0      0.39      0.26      0.53         0.08          1.27
# 4            1996.0      7.91      6.88      4.06         1.24         20.10
# 5            1997.0     15.34      8.67      9.01         2.02         35.01
# 6            1998.0     18.13     12.13     10.81         2.14         43.18
# 7            1999.0     23.32     15.69      9.67         2.45         51.17
# 8            2000.0     39.34     25.20     11.27         5.49         81.24
# 9            2001.0    139.32     72.85     23.57        18.26        253.88
# 10           2002.0    163.76     84.03     18.61        22.30        288.84
# ...

# %%
dfp.groupby(by=["Genre"]).sum()
# Out:
#               Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Genre
# Action              3273694.0    591.23    387.78     76.17       147.46
# Adventure            497893.0     38.81     25.06      8.73         8.05
# Fighting             758692.0    136.39     60.50     27.85        25.14
# Misc                 771047.0    222.05    120.46     33.22        40.41
# Platform             808555.0    193.60    108.56     43.09        32.53
# Puzzle               236825.0     33.50     24.04     14.98         6.33
# Racing              1165711.0    225.59    164.66     27.76        58.29
# Role-Playing        1429547.0    219.53    119.20    122.47        40.36
# Shooter             1734593.0    448.76    261.12     18.57        87.90
# Simulation           595963.0     92.12     67.29     26.16        17.14
# Sports              1892424.0    457.52    247.43     34.54        94.05
# Strategy             535812.0     33.25     25.21      4.34         6.61
#
# ...

# %%
df2 = (dfp.groupby(by=["Genre"])
       .sum()
       .drop(['Year_of_Release','Critic_Score' ,'Critic_Count', 'User_Count'],axis=1)
      )

# %% [markdown]
# ## Visualizing the data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="ticks",font_scale=1.3)

# %%
df2.plot.bar()
plt.xlabel('Genre',size=15)
plt.ylabel('Sales',size=15)
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# The figure shows that Action has the most global sales, and the least common genres in the world are adventure, puzzle, and strategy.

# %%
df3 =(
    df2.drop(['Global_Sales'], axis =1)
)

# %%
df3.plot.bar()
plt.xlabel('Genre',size=15)
plt.ylabel('Sales',size=15)
# Out:
# Text(0, 0.5, 'Sales')

# %%
fig_dims = (45, 15)

fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x="Year_of_Release",data=dfp,ax =ax, hue = "Genre")
plt.xlabel('Year',size=25)
plt.ylabel('Count',size=25)
plt.title("Genre vs. Year", size = 25)
# Out:
# Text(0.5, 1.0, 'Genre vs. Year')

# %% [markdown]
# This countplot shows the number of the games released is increasing. Also, it looks pink and red columns are higher than other genres from 2002 to 2015.

# %%
sns.countplot(y ='Genre' ,data = dfp)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Genre'>

# %% [markdown]
# Action is the most popular genre, and puzzle is the least common game.

# %% [markdown]
# ## Adding Weighted_Scored
# Weighted Score based on 45% of critic score and 55% User Score

# %%
dfp.User_Score = dfp.User_Score.astype(float)
dfp["Weighted Score"] = dfp["Critic_Score"]*0.45 + dfp["User_Score"]*0.55
dfp.head()
# Out:
#                                        Name Platform  Year_of_Release   Genre  \
# 0                                Darksiders     X360           2010.0  Action
# 1                                Frogger 3D      3DS           2011.0  Action
# 2  BeyBlade VForce: Super Tournament Battle       GC           2002.0  Action
# 3                 Power Rangers: Wild Force      GBA           2002.0  Action
# 4                  Tenchu: Shadow Assassins      Wii           2008.0  Action
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                           THQ      0.67      0.28      0.01         0.10
# 1  Konami Digital Entertainment      0.16      0.03      0.00         0.01
# 2                         Atari      0.16      0.04      0.00         0.01
# 3                           THQ      0.15      0.05      0.00         0.00
# 4                       Ubisoft      0.15      0.01      0.03         0.01
#
# ...

# %%
df4 = (dfp.groupby(by=["Genre"])
       .mean()
       .drop(['Year_of_Release', 'NA_Sales','EU_Sales','JP_Sales', 'Other_Sales', 'Global_Sales'], axis =1)
      )
df4
# Out:
#               Critic_Score  Critic_Count  User_Score  User_Count  \
# Genre
# Action           67.828834     30.204908    7.095828  202.201840
# Adventure        66.133065     24.947581    7.160887  114.770161
# Fighting         69.732804     28.873016    7.301852   66.544974
# Misc             67.460938     24.828125    6.849740   33.447917
# Platform         70.000000     26.784119    7.377171  114.590571
# Puzzle           70.694915     28.576271    7.250847   34.457627
# Racing           69.543890     25.882960    7.104303   73.750430
# Role-Playing     72.820225     33.042135    7.618539  331.209270
# Shooter          70.981481     37.114583    7.086458  392.393519
# Simulation       69.969697     23.282828    7.196633   92.771044
# Sports           74.170732     23.345705    7.110817   45.281018
# Strategy         73.123596     29.434457    7.352809  218.101124
#
#               Weighted Score
# Genre
# Action             34.425681
# Adventure          33.698367
# ...

# %%
a4_dims = (7, 15)
fig, ax = plt.subplots(figsize=a4_dims)
ax = sns.boxplot(x="Weighted Score", y="Genre", data=dfp)
#ax = sns.stripplot(x="Weighted Score", y="Genre", data=dfp,color=".3")
ax.set_title('BoxPlot of Weighted Scores by Genre')
ax.set_xlabel("Weighet Score")
ax.set_ylabel("Genre")
ax
# Out:
# <AxesSubplot:title={'center':'BoxPlot of Weighted Scores by Genre'}, xlabel='Weighet Score', ylabel='Genre'>

# %%
dfp[(dfp['Genre']== 'Racing')].min()
# Out:
# Name               007 Racing
# Platform                  3DS
# Year_of_Release          1997
# Genre                  Racing
# Publisher           505 Games
# NA_Sales                    0
# EU_Sales                    0
# JP_Sales                    0
# Other_Sales                 0
# Global_Sales             0.01
# Critic_Score               13
# Critic_Count                4
# User_Score                  1
# User_Count                  4
# Developer           2XL Games
# Rating                      E
# Weighted Score            6.4
# dtype: object

# %%
dfp[(dfp['Genre']== 'Racing')].max()
# Out:
# Name                          nail'd
# Platform                        XOne
# Year_of_Release                 2016
# Genre                         Racing
# Publisher          bitComposer Games
# NA_Sales                       15.68
# EU_Sales                       12.76
# JP_Sales                        4.13
# Other_Sales                     7.53
# Global_Sales                   35.52
# Critic_Score                      96
# Critic_Count                      90
# User_Score                       9.5
# User_Count                      1599
# Developer                  Zoo Games
# Rating                             T
# Weighted Score                47.985
# dtype: object

# %% [markdown]
# The figure shows that the averages of the scores do not have much differences, and the scores of racing varies. It has a big difference between the min and max. Although action is top sales category, the mean of the weighted score is slightly low.

# %%
dfp[(dfp['Weighted Score']== dfp['Weighted Score'].max())]
# Out:
#              Name Platform  Year_of_Release     Genre           Publisher  \
# 1904  SoulCalibur       DC           1999.0  Fighting  Namco Bandai Games
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 1904       0.0       0.0      0.34          0.0          0.34          98.0
#
#       Critic_Count  User_Score  User_Count Developer Rating  Weighted Score
# 1904          24.0         8.8       200.0     Namco      T           48.94

# %% [markdown]
# The highest weighted score is 94.9, Resident Evil 4 from action.
